# %% [markdown]
# # Task
# Construct a treemap and a sunburst chart using the dataset from "/content/USA_cars_datasets.csv".

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the `USA_cars_datasets.csv` file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the data into a pandas DataFrame and display the head and info to understand the data.

# %%
import pandas as pd

df = pd.read_csv('/content/USA_cars_datasets.csv')
display(df.head())
display(df.info())
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2499 non-null   int64
#  1   price         2499 non-null   int64
#  2   brand         2499 non-null   object
#  3   model         2499 non-null   object
#  4   year          2499 non-null   int64
#  5   title_status  2499 non-null   object
#  6   mileage       2499 non-null   float64
#  7   color         2499 non-null   object
#  8   vin           2499 non-null   object
#  9   lot           2499 non-null   int64
#  10  state         2499 non-null   object
#  11  country       2499 non-null   object
#  12  condition     2499 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 253.9+ KB
# None

# %% [markdown]
# ## Prepare data for treemap
#
# ### Subtask:
# Select relevant columns and aggregate the data as needed for the treemap visualization.

# %% [markdown]
# **Reasoning**:
# Select relevant columns, group by brand, sum the price, and reset the index to prepare the data for a treemap.

# %%
df_treemap = df[['brand', 'price']].groupby('brand')['price'].sum().reset_index()
display(df_treemap.head())
# Out:
#       brand   price
# 0     acura   21800
# 1      audi   55925
# 2       bmw  448750
# 3     buick  256305
# 4  cadillac  249410
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['price'].plot(kind='hist', bins=20, title='price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('brand').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2['price'].plot(kind='line', figsize=(8, 4), title='price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_3['brand'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_3, x='price', y='brand', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ## Generate treemap
#
# ### Subtask:
# Create a treemap visualization using the prepared data.

# %% [markdown]
# **Reasoning**:
# Create and display a treemap visualization using the prepared data as instructed.

# %%
import plotly.express as px

fig = px.treemap(data_frame=df_treemap, path=['brand'], values='price')
fig.update_layout(title='Total Price by Car Brand')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="89db29fe-d337-4d23-88a6-eedc4fc4e15c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89db29fe-d337-4d23-88a6-eedc4fc4e15c")) {                    Plotly.newPlot(                        "89db29fe-d337-4d23-88a6-eedc4fc4e15c",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eprice=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["acura","audi","bmw","buick","cadillac","chevrolet","chrysler","dodge","ford","gmc","harley-davidson","heartland","honda","hyundai","infiniti","jaguar","jeep","kia","land","lexus","lincoln","maserati","mazda","mercedes-benz","nissan","peterbilt","ram","toyota"],"labels":["acura","audi","bmw","buick","cadillac","chevrolet","chrysler","dodge","ford","gmc","harley-davidson","heartland","honda","hyundai","infiniti","jaguar","jeep","kia","land","lexus","lincoln","maserati","mazda","mercedes-benz","nissan","peterbilt","ram","toyota"],"name":"","parents":["","","","","","","","","","","","","","","","","","","","","","","","","","","",""],"values":[21800,55925,448750,256305,249410,5544976,246350,7681819,26758607,447610,54680,14830,73530,78048,157180,2800,328015,144610,115600,66440,36300,30300,16000,287040,3764536,1600,11050,6300],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed795 ...

# %% [markdown]
# ## Prepare data for sunburst
#
# ### Subtask:
# Select relevant columns and aggregate the data as needed for the sunburst visualization.

# %% [markdown]
# **Reasoning**:
# Select relevant columns, group by brand and model, count occurrences, reset index, and rename the count column for sunburst visualization data preparation.

# %%
df_sunburst = df[['brand', 'model']].groupby(['brand', 'model']).size().reset_index(name='count')
display(df_sunburst.head())
# Out:
#    brand model  count
# 0  acura  door      2
# 1  acura   mdx      1
# 2   audi     5      1
# 3   audi  door      2
# 4   audi    q5      1

# %% [markdown]
# ## Generate sunburst
#
# ### Subtask:
# Create a sunburst visualization using the prepared data.

# %% [markdown]
# **Reasoning**:
# Create a sunburst chart using the prepared data, setting the hierarchy path and values, and updating the layout with a title.

# %%
import plotly.express as px

fig = px.sunburst(data_frame=df_sunburst, path=['brand', 'model'], values='count')
fig.update_layout(title='Car Count by Brand and Model')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d38cc3f6-d4f6-4055-ad02-3388cbafa7b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d38cc3f6-d4f6-4055-ad02-3388cbafa7b9")) {                    Plotly.newPlot(                        "d38cc3f6-d4f6-4055-ad02-3388cbafa7b9",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["chevrolet\u002f1500","gmc\u002f1500","chevrolet\u002f2500","gmc\u002f2500hd","chrysler\u002f300","chevrolet\u002f3500","audi\u002f5","gmc\u002facadia","nissan\u002faltima","nissan\u002farmada","ford\u002fbus","chevrolet\u002fcab","ford\u002fcab","gmc\u002fcab","nissan\u002fcab","chevrolet\u002fcamaro","dodge\u002fcaravan","ford\u002fcargo","nissan\u002fcargo","dodge\u002fchallenger","dodge\u002fcharger","ford\u002fchassis","jeep\u002fcherokee","chevrolet\u002fcolorado","jeep\u002fcompass","ford\u002fconnect","ford\u002fconvertible","chevrolet\u002fcorvette","heartland\u002fcountry","bmw\u002fcoupe","cadillac\u002fcoupe","chevrolet\u002fcoupe","dodge\u002fcoupe","toyota\u002fcruiser","chevrolet\u002fcruze","chevrolet\u002fcutaway","ford\u002fcutaway","mazda\u002fcx-3","ford\u002fd","dodge\u002fdart","land\u002fdiscovery","acura\u002fdoor","audi\u002fdoor","bmw\u002fdoor","buick\u002fdoor","cadillac\u002fdoor","chevrolet\u002fdoor","chrysler\u002fdoor","dodge\u002fdoor","ford\u002fdoor","gmc\u002fdoor","honda\u002fdoor","hyundai\u002fdoor","jeep\u002fdoor","kia\u002fdoor","lincoln\u002fdoor","mazda\u002fdoor","mercedes-benz\u002fdoor","nissan\u002fdoor","ram\u002fdoor","chrysler\u002fdoors","dodge\u002fdoors","ford\u002fdoors","honda\u002fdoors","hyundai\u002fdoors","jaguar\u002fdoors","mercedes-benz\u002fdoors","nissan\u002fdoors","ford\u002fdr","ford\u002fdrw","dodge\u002fdurango","mercedes-benz\u002fe-class","ford\u002fecosport","ford\u002fedge","ford\u002fel","hyundai\u002felantra","buick\u002fenclave","buick\u002fencore","ford\u002fenergi","chevrolet\u002fequinox","ford\u002fescape","cadillac\u002fesv","ford\u002fexpedition","ford\u002fexplorer","ford\u002ff-150","ford\u002ff-650","ford\u002ff-750","ford\u002ffiesta","ford\u002fflex","ford\u002ffocus","kia\u002fforte","nissan\u002ffrontier","ford\u002ffusion","maserati\u002fghibli","mercedes-benz\u002fglc","mercedes-benz\u002fgle","lexus\u002fgx","ford\u002fhybrid","chevrolet\u002fimpala","dodge\u002fjourney","nissan\u002fjuke","nissan\u002fkicks","chevrolet\u002fld","gmc\u002flimited","bmw\u002fm","chevrolet\u002fmalibu","ford\u002fmax","nissan\u002fmaxima","acura\u002fmdx","dodge\u002fmpv","ford\u002fmpv","gmc\u002fmpv","honda\u002fmpv","hyundai\u002fmpv","infiniti\u002fmpv","jeep\u002fmpv","lexus\u002fmpv","nissan\u002fmpv","nissan\u002fmurano","ford\u002fmustang","lincoln\u002fnautilus","nissan\u002fnote","nissan\u002fnvp","chrysler\u002fpacifica","chevrolet\u002fpassenger","nissan\u002fpathfinder","chevrolet\u002fpickup","dodge\u002fpickup","ford\u002fpickup","heartland\u002fpioneer","chevrolet\u002fpk","dodge\u002fpk","ford\u002fpk","audi\u002fq5","infiniti\u002fq70","ford\u002franger","harley-davidson\u002froad\u002fstreet","nissan\u002frogue","ford\u002fse","nissan\u002fsedan","nissan\u002fsentra","bmw\u002fseries","mercedes-benz\u002fsl-class","chevrolet\u002fsonic","kia\u002fsorento","kia\u002fsoul","chevrolet\u002fspark","land\u002fsport","nissan\u002fsport","kia\u002fsportage","ford\u002fsrw","cadillac\u002fsrx","chevrolet\u002fsuburban","heartland\u002fsundance","ford\u002fsuv","chevrolet\u002ftahoe","ford\u002ftaurus","nissan\u002ftitan","heartland\u002ftrail","ford\u002ftransit","chevr ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The total price aggregated by car brand was visualized using a treemap, showing the contribution of each brand to the overall price.
# *   The count of cars by brand and model was visualized using a sunburst chart, illustrating the distribution of models within each brand.
#
# ### Insights or Next Steps
#
# *   Analyze the treemap to identify the car brands with the highest total value in the dataset.
# *   Examine the sunburst chart to identify which car models are most prevalent within the dominant brands.
